# %% [markdown]
# > [!TIP]
# > Please download the dataset at [Harvard Dataverse](https://doi.org/10.7910/DVN/OFN15B)

# %%
# required libraries
% pip install numpy matplotlib seaborn requests pillow pandas pycountry

# %%
from figure6 import *
from matplotlib.gridspec import GridSpec

# %%
data_dir= '/cta/mofadata/dataset_v1.2'
countries=get_countries(data_dir)

# %%
fig = plt.figure(figsize=(22, 12))
gs = GridSpec(nrows=len(categories), ncols=3, **{'width_ratios':[8,12,10],'height_ratios': [1, 1, 1], 'hspace': 0.2, 'bottom': 0.15}, figure=fig)

# a)
ax0 = fig.add_subplot(gs[:,0])
avg_img_per_country = get_image_per_country(countries)
plot_hist(avg_img_per_country, ax0)
ax0.text(-0.05, 1.035, 'a)', transform=ax0.transAxes, 
         size=16, va='top', ha='right')


# b)
ax1 = fig.add_subplot(gs[:,1])
plot_male_female_per_image(countries, ax=ax1, flags_per_row= 6, zoom = 0.14)
ax1.text(-0.05, 1.035, 'b)', transform=ax1.transAxes, 
            size=16, va='top', ha='right')


# c)
ax_list=[fig.add_subplot(gs[i,2]) for i in range(3)]
# plot_female_percentage(countries,ax_list,fig,0.12)
plot_country_genders_ratios(country_iso_codes=['FIN','MKD','TUR'],ax_list=ax_list,fig=fig, data_dir=data_dir)
ax_list[0].text(-0.05, 1.12, 'c)', transform=ax_list[0].transAxes,
                size=16, va='top', ha='right')



plt.tight_layout()
# plt.savefig("./some_path.pdf", 
#             dpi=300, 
#             bbox_inches='tight')
plt.show()
